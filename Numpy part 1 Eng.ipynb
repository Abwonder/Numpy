# %% [markdown]
# ### Numpy Basic ---- Part 1

# %%
### Numpy mean Numerical Python
import numpy as np 
#Created for Array manipulation and  mathematical operations

# %%
#Creating array and convert to array
l = [1,2,3,4,5]
l
## list
# Out:
# [1, 2, 3, 4, 5]

# %%
## converting the array to list
arr = np.array(l)

# %%
type(arr)## checking the datatype for validation
# ndarray ---  numpy data array
# Out:
# numpy.ndarray

# %%
# Perform same function as above
arr_as = np.asarray(l)
arr_as
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr_as)
# Out:
# numpy.ndarray

# %%
arr1 = np.array([[1,2,3] , [2,3,4]]) ## building two dimension array

# %% [markdown]
# ## visual example
# ![image.png](attachment:image.png)

# %%
arr.ndim ## checking array's dimension
# Out:
# 1

# %%
arr1.ndim
# Out:
# 2

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
## matrix building
mat = np.matrix(l)  ## matrix always have tow dimension at any point in time

# %%
mat.ndim   ## buttress above point
# Out:
# 2

# %%
np.asanyarray(l)   ## only convert what is not already array format
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.asanyarray(mat) ### it will not make any changes here
## as mat is a form of array already
# Out:
# matrix([[1, 2, 3, 4, 5]])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
a = arr  ## data was not created

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr[0] = 100  ## solo copy operation that impact any other varible pointed to this!!

# %%
arr
# Out:
# array([100,   2,   3,   4,   5])

# %%
a  ## this has changed too!!!
# Out:
# array([100,   2,   3,   4,   5])

# %%
b = np.copy(arr)  ## with this the data will not point to the same memory
## and they are now independent

## this is called DEEP copy

# %%
b
# Out:
# array([100,   2,   3,   4,   5])

# %%
b[0] = 234

# %%
b
# Out:
# array([234,   2,   3,   4,   5])

# %%
arr
# Out:
# array([100,   2,   3,   4,   5])

# %%
np.fromfunction(lambda i,j : i==j , (3,3))  ## i is the row and j the column
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %% [markdown]
# ### Explanation of the above Data
# ![image.png](attachment:image.png)

# %%
np.fromfunction(lambda i,j : i*j , (3,3)) ## applies the function to create
## matrix of 3x3 dimension!!!
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %% [markdown]
# ### explanations
# ![image.png](attachment:image.png)

# %%
list(i*i for i in range(5))
# Out:
# [0, 1, 4, 9, 16]

# %%
iterable  = (i*i for i in range(5))  ### creates a generator object!!!

# %%
iterable
# Out:
# <generator object <genexpr> at 0x000001CA67D62890>

# %%
np.fromiter(iterable,float)  ## ways to generate from list of tuple
## used fromiter, because its from an iterations (generator)
## output as float added the . period
# Out:
# array([ 0.,  1.,  4.,  9., 16.])

# %%
np.fromstring('23 45 56',sep  = ' ' ) ## generating array from string data of
## integers with space separator
# Out:
# array([23., 45., 56.])

# %%
np.fromstring('23,45,56',sep  = ',' )
# Out:
# array([23., 45., 56.])

# %%
arr
# Out:
# array([100,   2,   3,   4,   5])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr.ndim
# Out:
# 1

# %%
arr1.ndim
# Out:
# 2

# %%
arr.size
# Out:
# 5

# %%
arr1.size
# Out:
# 6

# %%
arr.shape   ## gives the dimesion
# Out:
# (5,)

# %%
arr1.shape
# Out:
# (2, 3)

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr1.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### The End
